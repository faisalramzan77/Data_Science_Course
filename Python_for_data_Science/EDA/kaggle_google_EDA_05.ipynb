# %% [markdown]
# # **Google Play Store EDA**

# %%
# Import Libraries
import pandas as pd
from ydata_profiling import ProfileReport

# %%
# Load Dataset
df = pd.read_csv('../Data/googleplaystore.csv')

# %%
# Generate the profiling report
prof = ProfileReport(df, title="Google Play Store Report")

# %%
# Save the report to HTML
prof.to_file("../Data/googleplaystore.html")
# Out:
# 100%|██████████| 13/13 [00:00<00:00, 17.98it/s]<00:01,  8.74it/s, Describe variable: Android Ver]
# Summarize dataset: 100%|██████████| 24/24 [00:01<00:00, 13.31it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:04<00:00,  4.63s/it]
# Render HTML: 100%|██████████| 1/1 [00:01<00:00,  1.34s/it]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 91.43it/s]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Data/googleplaystore.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# Lets have a look on data
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews Size     Installs  Type Price Content Rating  \
# 0     159   19      10,000+  Free     0       Everyone
# 1     967   14     500,000+  Free     0       Everyone
# 2   87510  8.7   5,000,000+  Free     0       Everyone
# 3  215644   25  50,000,000+  Free     0           Teen
# 4     967  2.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
# For Big Dataset random sample
df.sample(10)
# Out:
#                                                      App            Category  \
# 1214   Recipes Pastries and homemade pies More than 5...      FOOD_AND_DRINK
# 10474                                       Sat-Fi Voice       COMMUNICATION
# 6586                             BP and Sugar Test Prank           LIFESTYLE
# 6457                             Basket Manager 2018 Pro              SPORTS
# 610                                    Random Video Chat              DATING
# 6653                               Bar BQ Tonight Dublin           LIFESTYLE
# 10577                             Results for FL Lottery  NEWS_AND_MAGAZINES
# 8072                                           CX Summit        PRODUCTIVITY
# 8839                                           DS Vision            BUSINESS
# 8557                                      DM airdisk Pro               TOOLS
#
#        Rating Reviews Size    Installs  Type  Price Content Rating  \
# 1214      4.7   14065  7.1    500,000+  Free      0       Everyone
# 10474     3.4      37   14      1,000+  Free      0       Everyone
# 6586      4.0    7808  5.0  1,000,000+  Free      0       Everyone
# 6457      3.7      84  6.3      1,000+  Paid  $2.99       Everyone
# 610       NaN       3   16      1,000+  Free      0     Mature 17+
# 6653      NaN       0   22         50+  Free      0       Everyone
# 10577     4.6     146  7.1     10,000+  Free      0       Everyone
# 8072      NaN       1   17         50+  Free      0           Teen
# 8839      NaN       0   38          5+  Free      0       Everyone
# 8557      3.2      11   36      1,000+  Free      0       Everyone
#
#                  Genres        Last Updated Current Ver   Android Ver
# 1214       Food & Drink       June 12, 2018       1.2.2    4.1 and up
# 10474     Communication   November 21, 2014     2.2.1.5    2.2 and up
# 6586          Lifestyle    November 5, 2015       1.2.1    2.2 and up
# 6457             Sports      April 17, 2018         3.7    4.4 and up
# 610              Dating       July 15, 2018        4.20  4.0.3 and up
# 6653          Lifestyle        May 20, 2018    1.1.9371  4.0.3 and up
# 10577  News & Magazines   February 28, 2017         3.0    4.1 and up
# 8072       Productivity  September 20, 2017    7.12.0.1    4.2 and up
# 8839           Business        May 21, 2018         1.2    4.1 and up
# 8557              Tools  September 20, 2017       2.4.0  4.0.3 and up

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# # Write down all numeric variables and make them numeric
# 1. Rating
# 2. Reviews
# 3. Size
# 4. Price
# 5. Installs

# %%
# identify unique value
df['Size'].value_counts()
# Out:
# Size
# 11        198
# 12        196
# 14        194
# 13        191
# 15        184
#          ...
# 84          9
# 86          8
# 1.0         7
# 90          6
# 1,000+      1
# Name: count, Length: 183, dtype: int64

# %% [markdown]
# # Check that how many MBs in one KB and How to calculate
# 1. Convert KBs to MBs
# 2. Remove M from end of all numbers
# 3. Handle `varies with device`

# %% [markdown]
# # For Installs columns

# %%
df.Installs.isnull().sum()
# Out:
# np.int64(0)

# %%
df.Installs.value_counts()
# Out:
# Installs
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             907
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Free                 1
# Name: count, dtype: int64

# %% [markdown]
# # For Pricing

# %%
df['Price'].value_counts()
# Out:
# Price
# 0         10040
# $0.99       148
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $1.75         1
# $14.00        1
# $4.85         1
# $46.99        1
# $1.04         1
# Name: count, Length: 93, dtype: int64

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# # Day 2

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews Size     Installs  Type Price Content Rating  \
# 0     159   19      10,000+  Free     0       Everyone
# 1     967   14     500,000+  Free     0       Everyone
# 2   87510  8.7   5,000,000+  Free     0       Everyone
# 3  215644   25  50,000,000+  Free     0           Teen
# 4     967  2.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df['Size'].value_counts()
# Out:
# Size
# 11        198
# 12        196
# 14        194
# 13        191
# 15        184
#          ...
# 84          9
# 86          8
# 1.0         7
# 90          6
# 1,000+      1
# Name: count, Length: 183, dtype: int64
